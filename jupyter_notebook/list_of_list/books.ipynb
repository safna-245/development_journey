# %%
books_data = [
    ["The Hobbit", "Fantasy", 15, 1937, 4.8],           # 0
    ["Dune", "Sci-Fi", 18, 1965, 4.7],                 # 1
    ["Project Hail Mary", "Sci-Fi", 22, 2021, 4.9],    # 2
    ["Atomic Habits", "Self-Help", 16, 2018, 4.8],     # 3
    ["1984", "Dystopian", 12, 1949, 4.6],             # 4
    ["The Silent Patient", "Mystery", 14, 2019, 4.5],  # 5
    ["Sapiens", "History", 20, 2014, 4.7],            # 6
    ["Harry Potter", "Fantasy", 25, 1997, 4.9],        # 7
    ["Educated", "Memoir", 17, 2018, 4.4],             # 8
    ["Klara and the Sun", "Sci-Fi", 13, 2021, 4.2]     # 9
]

# %%
  #Task 0.1: Print the titles of all books that contain more than 10 character
titles = [b[0] for b in books_data if len(b[0])>10]

titles
# Out:
# ['Project Hail Mary',
#  'Atomic Habits',
#  'The Silent Patient',
#  'Harry Potter',
#  'Klara and the Sun']

# %%
#Task 0.2: Find and print all titles that start with the word "The".
title = [b[0] for b in books_data if b[0].startswith("The")]

title
# Out:
# ['The Hobbit', 'The Silent Patient']

# %%
#Task 1.1: Create a set or list containing all unique genres present in the dataset (without duplicates).
genres = {b[1] for b in books_data if books_data.count(b) == 1}

genres
# Out:
# {'Dystopian', 'Fantasy', 'History', 'Memoir', 'Mystery', 'Sci-Fi', 'Self-Help'}

# %%
#Task 1.2: Count how many total books belong to the "Sci-Fi" genre.

count =len([b[1] for b in books_data if b[1] =="Sci-Fi" ])

count
# Out:
# 3

# %%
#Task 2.1: Calculate the total cost if a customer buys one copy of every book in the dataset.

total_cost = sum([b[2] for b in books_data])

total_cost
# Out:
# 172

# %%
#Task 2.2: Find and print the title and price of the cheapest book (lowest price).
lowest = [b[2] for b in books_data]

lowest_price = min(lowest)

result = [[b[0],b[2]] for b in books_data if b[2] == lowest_price]

result
# Out:
# [['1984', 12]]

# %%
#Task 3.1: Print each book's title along with its age in years (using 2026 as the current year).

title = [[b[0],2026 - b[3]] for b in books_data]

title
# Out:
# [['The Hobbit', 89],
#  ['Dune', 61],
#  ['Project Hail Mary', 5],
#  ['Atomic Habits', 8],
#  ['1984', 77],
#  ['The Silent Patient', 7],
#  ['Sapiens', 12],
#  ['Harry Potter', 29],
#  ['Educated', 8],
#  ['Klara and the Sun', 5]]

# %%
#Task 3.2: Filter and display all books published before the year 2000.
books = [b[0] for b in books_data if b[3]<2000]

books
# Out:
# ['The Hobbit', 'Dune', '1984', 'Harry Potter']

# %%
#Task 4.1: Calculate the average rating of all 10 books in the dataset.
rating = sum([b[4] for b in books_data])/len(books_data)

rating
# Out:
# 4.65

# %%
#Task 4.2: Count how many books have a rating of 4.8 or higher.
higher_rating = len([b[4] for b in books_data if b[4] >= 4.8])

higher_rating
# Out:
# 4

# %%
#Capstone Task: Write a script to find the title of the most expensive "Sci-Fi" book published after 2010.
sci_fi_books = [b for b in books_data if b[1] == "Sci-Fi" and b[3] >2010]

price = [b[2] for b in sci_fi_books]

expensive = max(price)

expensive_scifi_book = [b[0] for b in sci_fi_books if b[2] == expensive]

print(expensive_scifi_book)
# Out:
# ['Project Hail Mary']
